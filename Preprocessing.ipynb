# %% [markdown]
# # **Importazione Librerie**

# %%
import pandas as pd
import re

# %% [markdown]
# # **Importazione dataset**

# %%
df = pd.read_csv("data/data.csv")
print(df.head())
# Out:
#    id        title                                               body  \
# 0   1      urgente  Desidero segnalare che richiesta maternità Gra...
# 1   2        ferie       nota spese da approvare thx era solo un'idea
# 2   3     password  Buongiorno, internet non funziona Grazie per l...
# 3   4  problema pc                                  schermo sfarfalla
# 4   5    richiesta  gli straordinari non sono stati pagati inoltre...
#
#           category priority
# 0  Amministrazione     alta
# 1  Amministrazione    bassa
# 2          Tecnico    media
# 3          Tecnico     alta
# 4  Amministrazione     alta

# %% [markdown]
# **Concatenazione delle colonne "title" e "body"**

# %%
df["full_text"] = df["title"] + " " + df["body"]

# %% [markdown]
# # **Preprocessing del testo**

# %% [markdown]
# **Conversione delle lettere da maiuscole a minuscole**

# %%
df.full_text = df.full_text.str.lower()
print(df.full_text.head())
# Out:
# 0    urgente desidero segnalare che richiesta mater...
# 1    ferie nota spese da approvare thx era solo un'...
# 2    password buongiorno, internet non funziona gra...
# 3                        problema pc schermo sfarfalla
# 4    richiesta gli straordinari non sono stati paga...
# Name: full_text, dtype: object

# %% [markdown]
# **Rimozione caratteri speciali e doppi spazi**

# %%
pattern = r"[!?,.;:()\[\]{}@%*/\\|=+]"
df["full_text"] = df["full_text"].str.replace(pattern, " ", regex = True)
df["full_text"] = df["full_text"].str.replace(r"\s+", " ", regex=True).str.strip()

print(df["full_text"].head())
# Out:
# 0    urgente desidero segnalare che richiesta mater...
# 1    ferie nota spese da approvare thx era solo un'...
# 2    password buongiorno internet non funziona graz...
# 3                        problema pc schermo sfarfalla
# 4    richiesta gli straordinari non sono stati paga...
# Name: full_text, dtype: object

# %% [markdown]
# # **Salvataggio dataframe preprocessato**

# %%
df.to_csv("data/dataset_clean.csv", index = False)
